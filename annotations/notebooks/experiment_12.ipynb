s_coding_001 = [3.26E-03, 2.68E-03, 3.15E-03, 2.37E-03, 2.29E-03, 2.54E-03, 2.34E-03, 2.22E-03, 2.26E-03, 2.70E-03]
s_noncoding_001 = [3.06E-04, 3.59E-04, 3.06E-04, 3.45E-04, 3.66E-04, 3.57E-04, 4.01E-04, 3.06E-04, 3.06E-04, 3.53E-04]
s0_001 = [1.0286, 1.0297, 1.0299, 1.0272, 1.0325, 1.0003, 1.0312, 1.0003, 1.0002, 1.0350]
h2_coding_001 = [0.4214, 0.3936, 0.4193, 0.4147, 0.3526, 0.3930, 0.3789, 0.4032, 0.3827, 0.4149]
h2_noncoding_001 = [0.3043, 0.3213, 0.3142, 0.3231, 0.3231, 0.4005, 0.3322, 0.4014, 0.4055, 0.3029]
h2_total_001 = [0.7257, 0.7149, 0.7335, 0.7378, 0.6757, 0.7935, 0.7111, 0.8046, 0.7882, 0.7179]
cost_001 = [1.4720910, 1.4730600, 1.4734550, 1.4735080, 1.4736510, 1.4736580, 1.4741390, 1.4745590, 1.4747340, 1.4752200]

p_coding = [p_coding_005, p_coding_003, p_coding_001]
p_noncoding = [p_noncoding_005, p_noncoding_003, p_noncoding_001]
s_coding = [s_coding_005, s_coding_003, s_coding_001]
s_noncoding = [s_noncoding_005, s_noncoding_003, s_noncoding_001]
s0 = [s0_005, s0_003, s0_001]
h2_coding = [h2_coding_005, h2_coding_003, h2_coding_001]
h2_noncoding = [h2_noncoding_005, h2_noncoding_003, h2_noncoding_001]
h2_total = [h2_total_005, h2_total_003, h2_total_001]
cost = [cost_005, cost_003, cost_001]

# %%
save = True
outf = "experiment_12.ld_accuracy_effect.png"
fig, axs = plt.subplots(nrows=3, ncols=3, figsize=(12,6), constrained_layout=True, dpi=150)
# p_coding   p_noncoding   s0
# s_coding   s_noncoding   cost
# h2_coding  h2_noncoding  h2_total
data = [[p_coding, p_noncoding, s0], [s_coding, s_noncoding, cost], [h2_coding, h2_noncoding, h2_total]]
titles = [["p_coding", "p_noncoding", "s0"],
          ["s_coding", "s_noncoding", "cost"],
          ["h2_coding", "h2_noncoding", "h2_total"]]
true_vals = [[5.E-3, 5.E-4, 1.0], [2.5E-3, 2.5E-4, None], [0.3895054414756651, 0.29139689724450596, 0.7]]
log_scale = ["p_coding", "p_noncoding", "s_coding", "s_noncoding"]
x_tick_labels = ["0.05", "0.03", "0.01"]
x_tick_pos = [1, 2, 3]
colors = ["#e69f00","#56b4e9","#009e73"]
y_spread = 0.15
n_runs = 10
for i in range(3):
    for j in range(3):
        ax = axs[i][j]
        for xxi, xx in enumerate(x_tick_pos):
            x = xx + y_spread*(0.5-np.random.rand(n_runs))
            y = data[i][j][xxi]
            ax.plot(x,y,color=colors[xxi],ls=' ',marker='o',ms=4)
        true_val = true_vals[i][j]
        if not true_val is None:
            ax.axhline(true_val, ls='--', lw=1, color="#cc79a7")
        ax.set_xticks(x_tick_pos)
        ax.set_xticklabels(x_tick_labels)
        title = titles[i][j]
        ax.set_title(title)
        if title in log_scale:
            ax.set_yscale('log')
if save:
    plt.savefig(outf)

# %%
31160.435318053205*5.E-3*2.5E-3, 2331175.1779560475*5.E-4*2.5E-4
# Out:
# (0.3895054414756651, 0.29139689724450596)
